# %%
import pandas as pd

dt = pd.read_csv('pivot_df.csv')

# %%
dt = dt.set_index('author')

# %%
import pandas as pd

df = pd.read_csv('curricula_backup.tsv', sep='\t')
df
# Out:
#                  author                      title comment   curriculum  id  \
# 0          Андреев Л.Н.                  Жили-были     NaN  19 ИРЛ 2 ст   1
# 1          Андреев Л.Н.                       Иуда     NaN  19 ИРЛ 2 ст   1
# 2          Андреев Л.Н.  Рассказ о семи повешенных     NaN  19 ИРЛ 2 ст   1
# 3         Бальмонт К.Д.                        NaN     NaN  19 ИРЛ 2 ст   1
# 4           Брюсов В.Я.                        NaN     NaN  19 ИРЛ 2 ст   1
# ...                 ...                        ...     ...          ...  ..
# 10301         Шиллер Ф.                 Разбойники     NaN     91 ПСОУЗ  50
# 10302             Эсхил       Прометей прикованный     NaN     91 ПСОУЗ  50
# 10303  Достоевский Ф.М.   Преступление и наказание     NaN     91 ПСОУЗ  50
# 10304       Куприн А.И.         Гранатовый браслет     NaN     91 ПСОУЗ  50
# 10305     Некрасов Н.А.                Коробейники     NaN     91 ПСОУЗ  50
#
#        year  grade priority
# ...

# %%
df = pd.read_csv('for_clust_autors_titles_counted.csv')
df.set_index('author', inplace = True)

# %%
df
# Out:
#                 1919  1922  1932  1933  1934  1938  1940  1941  1942  1944  \
# author
# Абашидзе И.В.    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Абрамов Ф.А.     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Аверченко А.Т.   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Авижюс Й.        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Адамович А.М.    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...              ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# Эсхил            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Ян В.Г.          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   1.0   1.0
# Яновский Ю.И.    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Ясенский Б.      NaN   NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# народ           36.0  18.0   1.0   9.0   4.0   3.0  34.0  10.0   9.0   NaN
#
# ...

# %% [markdown]
# иерархическая
# K-Modes
# дбскан

# %% [markdown]
# график локтя
# визуалиазция кластеров

# %% [markdown]
# качественные расстояния

# %% [markdown]
# кластеризация годов

# %%
df.
X = df

# %%
import scipy.spatial.distance
from sklearn.cluster import DBSCAN

clustering_db = DBSCAN(metric = 'hamming', min_samples=5).fit(X)
dt["clust_res"] = clustering_db.labels_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17456\3468201505.py in <module>
#       2 from sklearn.cluster import DBSCAN
#       3
# ----> 4 clustering_db = DBSCAN(metric = 'hamming', min_samples=5).fit(X)
#       5 dt["clust_res"] = clustering_db.labels_
#
# C:\anaconda\lib\site-packages\sklearn\cluster\_dbscan.py in fit(self, X, y, sample_weight)
#     344             Returns a fitted instance of self.
#     345         """
# --> 346         X = self._validate_data(X, accept_sparse="csr")
#     347
#     348         if not self.eps > 0.0:
#
# C:\anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# ...

# %%
from sklearn.metrics import jaccard_score
import numpy as np

# Использование DBSCAN с метрикой Жаккара
clustering_db = DBSCAN(metric='jaccard', min_samples=10, eps=0.5).fit(X)
dt["clust_res"] = clustering_db.labels_

print(dt["clust_res"])
# Out:
# author
# Абашидзе И.В.     0
# Абрамов Ф.А.      0
# Аверченко А.Т.    1
# Авижюс Й.         0
# Адамович А.М.     0
#                  ..
# Эсхил             1
# Ян В.Г.          -1
# Яновский Ю.И.     0
# Ясенский Б.       1
# народ             0
# Name: clust_res, Length: 461, dtype: int64
# C:\anaconda\lib\site-packages\sklearn\metrics\pairwise.py:1875: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)

# %%
print(dt["clust_res"])
# Out:
# author
# Абашидзе И.В.     0
# Абрамов Ф.А.      0
# Аверченко А.Т.    1
# Авижюс Й.         0
# Адамович А.М.     0
#                  ..
# Эсхил             1
# Ян В.Г.          -1
# Яновский Ю.И.     0
# Ясенский Б.       1
# народ             0
# Name: clust_res, Length: 461, dtype: int64

# %%
dt['clust_res'].value_counts()
# Out:
# clust_res
#  1    265
#  0    178
# -1     18
# Name: count, dtype: int64

# %%
dt.loc['Адамович Г.В.']
# Out:
# 1919         0
# 1922         0
# 1932         0
# 1933         0
# 1934         0
# 1938         0
# 1940         0
# 1941         0
# 1942         0
# 1944         0
# 1946         0
# 1947         0
# 1948         0
# 1949         0
# 1950         0
# 1951         0
# 1954         0
# 1956         0
# 1957         0
# 1958         0
# 1959         0
# 1960         0
# 1961         0
# 1964         0
# 1965         0
# 1973         0
# 1974         0
# 1975         0
# 1976         0
# 1977         0
# 1978         0
# 1979         0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1991         0
# clust_res    1
# Name: Адамович Г.В., dtype: int64

# %%
dt[dt['clust_res']==-1]
# Out:
#                       1919  1922  1932  1933  1934  1938  1940  1941  1942  \
# author
# Антоновская А.А.         0     0     0     0     0     0     0     0     1
# Бараташвили Н.           0     0     0     0     0     0     0     0     0
# Бородин С.П.             0     0     0     0     0     0     0     0     1
# Брежнев Л.И.             0     0     0     0     0     0     0     0     0
# Брюсов В.Я.              1     1     0     1     1     1     1     1     1
# Бэкон Ф.                 0     0     0     0     0     0     0     1     0
# Гроссман В.С.            0     0     0     0     0     0     0     0     0
# Зульфия                  0     0     0     0     0     0     0     0     0
# Инбер В.М.               0     0     0     0     0     0     0     0     0
# Кьюсак Д.                0     0     0     0     0     0     0     0     0
# Мор Т.                   0     0     0     0     0     0     0     1     0
# ...
